# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("CSVs/dataframe spotify 2020-21 (Limpio).csv", index_col = 0)
df
# Out:
#                                 Artist                           Song Name  \
# Index
# 1                            MÃ¥neskin                             Beggin'
# 2                        The Kid LAROI           STAY (with Justin Bieber)
# 3                       Olivia Rodrigo                            good 4 u
# 4                           Ed Sheeran                          Bad Habits
# 5                            Lil Nas X   INDUSTRY BABY (feat. Jack Harlow)
# ...                                ...                                 ...
# 1552                          Dua Lipa                           New Rules
# 1553                    Jorge & Mateus                  Cheirosa - Ao Vivo
# 1554                    Camila Cabello           Havana (feat. Young Thug)
# 1555   DadÃ¡ BoladÃ£o, Tati Zaqui, OIK          Surtada - Remix Brega Funk
# 1556                      Taylor Swift  Lover (Remix) [feat. Shawn Mendes]
#
#         Streams Release Date  \
# Index
# ...

# %%
x = df["Loudness"].values
y = df["Danceability"].values

intervalos = range(-20, 0)

plt.hist(x=x, bins=(intervalos), color='#F2AB6D', rwidth=0.85)
plt.title('Histograma de edades - matplotlib - codigopiton.com')
plt.xlabel('Loudness')
plt.ylabel('Danceability')
plt.xticks(intervalos)
# Out:
# ([<matplotlib.axis.XTick at 0x18a599325f0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
x = df["Tempo"].values
y = df["Danceability"].values

intervalos = 60,80,100,120,135,150,170,190,200

plt.hist(x=x, bins=(intervalos), color='#F2AB6D', rwidth=0.85)
plt.title('Histograma de edades - matplotlib - codigopiton.com')
plt.xlabel('Tempo')
plt.ylabel('Danceability')
plt.xticks(intervalos)
# Out:
# ([<matplotlib.axis.XTick at 0x18a597e2380>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
x = df["Loudness"].values
y = df["Danceability"].values


#edades = [12, 15, 13, 12, 18, 20, 19, 20, 13, 12, 13, 17, 15, 16, 13, 14, 13, 17, 19]
intervalos = -20,-15,-9,-8,-7,-6,-5,-4,-3,-2,-1,0,1,2

plt.scatter(x=x, y=y ,color='#F2AB6D')
plt.title('Histograma de edades - matplotlib - codigopiton.com')
plt.xlabel('Loudness')
plt.ylabel('Danceability')
plt.xticks(intervalos)
# Out:
# ([<matplotlib.axis.XTick at 0x18a5980c940>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(20,5))
sns.boxplot(df["Loudness"], color="sienna");
# Out:
# C:\Users\Señor Topo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,5))
sns.violinplot(df["Loudness"], color='deeppink');
# Out:
# C:\Users\Señor Topo\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
mask =(df["Loudness"].values > -2)
df[mask]
# Out:
#                                                   Artist  \
# Index
# 108                                                 Sech
# 150                                       Mari Fernandez
# 229                                                TWICE
# 652                                       Jonas Esticado
# 746                                        Sfera Ebbasta
# 1097                                               Niack
# 1160                                                  IU
# 1250                                           Sub Urban
# 1395   PEDRO SAMPAIO, Felipe Original, JS o MÃ£o de Ouro
#
#                             Song Name  Streams Release Date  \
# Index
# 108                      Sal y Perrea  6635076   2021-04-15
# 150                    NÃ£o, NÃ£o Vou  5652272   2021-04-29
# 229                      Alcohol-Free  5259503   2021-06-11
# 652                    Investe Em Mim  5191001   2019-12-13
# 746              Baby (with J Balvin)  7276896   2020-12-18
# ...

# %%
mask =(df["Loudness"].values < -20)
df[mask]
# Out:
#                                             Artist           Song Name  \
# Index
# 671    Mykola Dmytrovych Leontovych, John Williams  Carol of the Bells
# 1500                                        Eminem  Alfred - Interlude
# 1547                                      JACKBOYS            JACKBOYS
#
#        Streams Release Date                                  Genre  Loudness  \
# Index
# 671    7993078         1990                         ['soundtrack']   -22.507
# 1500   8030151   2020-01-17  ['detroit hip hop', 'hip hop', 'rap']   -20.430
# 1547   5363493   2019-12-27                        ['rap', 'trap']   -25.166
#
#        Popularity  Danceability  Tempo  Energy  Chord
# Index
# 671          51.0         0.418     46   0.106  G#/Ab
# 1500         57.0         0.429     74   0.231      F
# 1547         56.0         0.413    123   0.130      C

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);

# %%
dur_2021 = 3.20 
dur_2010 = 3.45

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize = (15,10))
sns.set_theme(style="dark")
plt.style.use("seaborn")
sns.set_context("poster")

font1 = {'family':'serif','color':'black','size':25}
font2 = {'family':'serif','color':'grey','size':20}

ax = sns.lineplot(x=["2010","2011","2012","2013","2014",
                    "2015","2016","2017","2018","2019",
                    "2020-21",], y= [3.83 ,4.04,3.73,3.90,3.73,3.72,3.67,3.70,
                                     3.61,3.34,3.24],
                    color = "b")


plt.xlabel("Año", font2)
plt.ylabel("Duración (minutos)", font2)
plt.title("Comparación duración media",font1)
# Out:
# Text(0.5, 1.0, 'Comparación duración media')

# %%
plt.figure(figsize = (15,10))
sns.set_theme(style="dark")
plt.style.use("seaborn")
sns.set_context("poster")

font1 = {'family':'serif','color':'black','size':25}
font2 = {'family':'serif','color':'grey','size':20}

ax = sns.lineplot(x=["2010","2011","2012","2013","2014",
                    "2015","2016","2017","2018","2019",
                    "2020-21",], y= [-4.9,-5.01,-4.85,-5.14,-5.77,-5.62,-6.03,-5.61,-5.67,-5.77,-6.34],
                    color = "b")


plt.xlabel("Año", font2)
plt.ylabel("dBs", font2)
plt.title("Comparación dBs de media",font1)
# Out:
# Text(0.5, 1.0, 'Comparación dBs de media')

# %%
# Canción con mas visitas en 2021:
# Blinding Lights by The weeknd. 2.836M Spotify

# Blinding Lights by The weeknd. 649M Youtube

# Blinding Lights by The weeknd. 20.3M SoundCloud

# %%
sns.set_theme(style="whitegrid")
font1 = {'family':'serif','color':'black','size':25}
font2 = {'family':'serif','color':'grey','size':20}

ax = sns.barplot(x=["Spotify","Youtube","SoundCloud"], y= [2836,649,20.3])
plt.xlabel("Plataformas", font2)
plt.ylabel("Visitas (en millones)", font2)
plt.title("Blinding Lights by The weeknd (2022)",font1)
# Out:
# Text(0.5, 1.0, 'Blinding Lights by The weeknd (2022)')

# %%
canciones = ["Bruno Mars - Uptown Funk",
         "Ed Sheeran - Thinking out Loud",
         "OMI - Cheerleader",
         "Sam Smith - Stay With Me",
         "Maroon 5 - Animals",
         "Nicky Jam (feat Enrique Iglesias) - El Perdón",
         "Justin Bieber - What Do You Mean?",
         "Adele - Hello",]

tempos = [115,
                   79,
                   100,
                   84,
                   80,
                   90,
                   125,
                   79,]

diccionario = pd.DataFrame(list(zip(canciones,tempos)), columns = ['Canción','BPM'])

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use("seaborn-poster")

f, ax = plt.subplots(figsize=(6, 6))

sns.set_color_codes("pastel")
sns.barplot(x="BPM", y="Canción", data=diccionario,
            label="Tempos")
plt.title("Tempo de las canciones más famosas del 2015")
sns.despine(left=True, bottom=False);
