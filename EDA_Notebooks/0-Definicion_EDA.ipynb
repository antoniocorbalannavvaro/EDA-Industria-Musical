# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# <h2>¿Qué estilo de música debería producir?</h2> (Muy muy provisional este título ¡OJO!)

# %% [markdown]
# ### TEMA

# %% [markdown]
# La idea principal de este análisis es determinar, a día de hoy (2022), cuáles son los géneros más escuchados y en qué plataformas se distribuyen principalmente.
#
# La finalidad del análisis es poder proporcionar información determinante, basada en datos y estadísticas, a pequeñas y grandes productoras musicales, para poder tomar decisiones de negocio que lleven al éxito.

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# - ¿Qué estilo de música es el más escuchado y cuál debería producir?
# - ¿Es el regetón es el más escuchado?
# - ¿A qué público va dirigida mi música? (Publicidad)
# - ¿Dónde debería situar mi estudio/productora?
# - ¿A qué plataformas le doy más prioridad a la hora de distribuir mi música (Spotify, soundcloud, youtube...etc)?
# - ¿Debería distribuirlo en formnato físico o es ya una práctica desfasada?

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Para resolver las 3 primeras hipótesis utilizaré los siguientes datasets de [www.kaggle.com](https://www.kaggle.com/) :
# * Spotify Top 200 Charts (2020-2021) [Link](https://www.kaggle.com/sashankpillai/spotify-top-200-charts-20202021)
# * Top Spotify songs from 2010-2019 - BY YEAR [Link](https://www.kaggle.com/leonardopena/top-spotify-songs-from-20102019-by-year)
#
# También utilizaré la [API de spotify](https://developer.spotify.com/documentation/web-api/) para complementar y contrastar la información de los anteriores datasets.
#
# Para utilizar está API seguiré el tutorial de esta página. [Tutorial API Spotify (Python)](https://spotipy.readthedocs.io/en/2.19.0/)

# %% [markdown]
# Para determinar en qué plataforma se debe priorizar a la hora de distribuir la música utilizaré WebScraping para comparar el número de visitas de las canciones Top (en Spotify) que saquemos en las anteriores hipótesis con el número de visitas que tienen esas mismas canciones pero en las otras principales plataformas músicales ([SoundCloud](https://soundcloud.com/es), [AppleMusic](https://www.apple.com/es/apple-music/), [Last.fm](https://www.last.fm/es/) y [Youtube](https://www.youtube.com/))

# %% [markdown]
# En relación a la última hipótesis, me apoyaré en los datos que pueda encontrar en [Wikipedia](https://es.wikipedia.org/wiki/Wikipedia:Portada)
#
# Compararé las ventas en físico de los EPs de los Top mundiales actuales con las ventas de los Top mundiales de hace 10 años para ver si las ventas en formato físico se mantienen igual, suben, o bajan.

# %%
import pandas as pd

# %%
df1 = pd.read_csv("Spotify Top 200 Charts (2020-2021).csv", index_col = 0)
df1.head()
# Out:
#        Highest Charting Position  Number of Times Charted  \
# Index
# 1                              1                        8
# 2                              2                        3
# 3                              1                       11
# 4                              3                        5
# 5                              5                        1
#
#       Week of Highest Charting                          Song Name     Streams  \
# Index
# 1       2021-07-23--2021-07-30                            Beggin'  48,633,449
# 2       2021-07-23--2021-07-30          STAY (with Justin Bieber)  47,248,719
# 3       2021-06-25--2021-07-02                           good 4 u  40,162,559
# 4       2021-07-02--2021-07-09                         Bad Habits  37,799,456
# 5       2021-07-23--2021-07-30  INDUSTRY BABY (feat. Jack Harlow)  33,948,454
#
#                Artist Artist Followers                 Song ID  \
# Index
# ...

# %%
df2 = pd.read_csv("Top Spotify songs from 2010-2019 - BY YEAR.csv", encoding = "latin1", index_col = 0)
df2.head()
# Out:
#    Unnamed: 0                 title      artist        top genre  year  bpm  \
# 0           1      Hey, Soul Sister       Train       neo mellow  2010   97
# 1           2  Love The Way You Lie      Eminem  detroit hip hop  2010   87
# 2           3               TiK ToK       Kesha        dance pop  2010  120
# 3           4           Bad Romance   Lady Gaga        dance pop  2010  119
# 4           5  Just the Way You Are  Bruno Mars              pop  2010  109
#
#    nrgy  dnce  dB  live  val  dur  acous  spch  pop
# 0    89    67  -4     8   80  217     19     4   83
# 1    93    75  -5    52   64  263     24    23   82
# 2    84    76  -3    29   71  200     10    14   80
# 3    92    70  -4     8   71  295      0     4   79
# 4    84    64  -5     9   43  221      2     4   78
